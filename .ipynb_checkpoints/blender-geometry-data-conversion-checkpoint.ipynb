# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Data

# %%
# this block is for testing

# C:\Users\chris\ChrisdeMontigny\Nefari0 Repository\Python\Blender
# read_data_x = open("C:\\Users\chris\ChrisdeMontigny\\Nefari0 Repository\Python\Blender\coord_data_x.txt","r")
# x_vector = read_data_x.read()
# read_data_x.close()
# write_data_y = open("coord_data_y.txt","r+")
# write_data_y.write(str(y))
# write_data_y.close()
# # print(data_vector)

# print(x_vector)

# %% [markdown]
# ### Extract Coordinates from External Script

# %%
# paste this code into script to extract/export coordinate data.
# this code is not meant to be executed in this script
# read_data_x = open("coord_data_x.txt","w")
read_data_x = open("C:\\Users\chris\ChrisdeMontigny\\Nefari0 Repository\Python\Blender\coord_data_x.txt","w")
read_data_y = open("C:\\Users\chris\ChrisdeMontigny\\Nefari0 Repository\Python\Blender\coord_data_y.txt","w")

for i in range(len(x)):
    y_list = read_data_y.write(str(y[i]) + ',')
#     x_list = read_data_x.write('[' + str(x[i]) + ']')
    x_list = read_data_x.write(str(x[i]) + ',')
read_data_y.close()
read_data_x.close()
# u = list(x_list.split(' '))

# x_str = str(y)
# read_data_x = open("coord_data_x.txt","w")
# x_list = read_data_x.write(x_str)
# read_data_x.close()

# %% [markdown]
# ### Import Data

# %%
###### This cell will import data from external scripts

# x axis data
read_data_x = open("coord_data_x.txt","r")
x_list = read_data_x.read()
read_data_x.close()
data_vector_x = list(x_list.split(','))

# y / u / fx axis data
read_data_y = open("coord_data_y.txt","r")
y_list = read_data_y.read()
read_data_y.close()
data_vector_y = list(y_list.split(','))
# print(data_vector_x)
# print(data_vector_y)

# convert imported plots from strings into floats
# xy coordinates
x = []
y = []
for i in range(len(data_vector_x)-1):
#     unit = [float(data_vector_x[i])]
    x.append(float(data_vector_x[i]))
    y.append(float(data_vector_y[i]))

# %% [markdown]
# ### Calculate and Export Plots

# %%
# ---- x / u coordinate declarations ---- #
# u = np.linspace(-4,4,200) # linear
# u = np.linspace(0,2*np.pi,200) # circular

#  ---- y / fx coordinate declarations ---- #
# default # example function
# fx = 4+np.cos(3*u)+np.sin(2*u)
    
# this displays how the Blender geometry will look when the generated mesh
# array (shown below) is executed in the bpy api in Blender.
plt.plot(x,y)

# this generates an array of arrays that contain 3 elements each. Each
# of the 3 element arrays contains an x,y,z coordinate (u[i],fx[i], z=0).
# these coordinates are converted into strings for exportation
mesh = []
mesh_string = ''
for i in range(len(x)):
    
#     string coordinates
    xyz_str = []
    xyz_str.append('<' + str(x[i]) + '<')
    xyz_str.append('<' + str(y[i]) + '<')
    xyz_str.append('<' + str(0) + '<')
    mesh_string += '>' + str(xyz_str) + '>'
    
#     numerical coordindats
    xyz = []
    xyz.append(x[i])
    xyz.append(y[i])
    xyz.append(0)
    mesh.append(xyz)
    
print(mesh_string)

# -- this set of code saves the 'mesh' array into a text file -- #
save_mesh = open("mesh_data.txt","w")
save_mesh.write(mesh_string)
save_mesh.close()
# ------------------------------------------------------------- #

plt.axis('square')
plt.grid()
plt.show()
# Out:
379790579888417<', '<0.028953308106804996<', '<0<']>>['<-0.045354521622082505<', '<0.020594831041235266<', '<0<']>>['<-0.04556626907861964<', '<0.012531265630257889<', '<0<']>>['<-0.044561943551607745<', '<0.004944608318487034<', '<0<']>>['<-0.04248936419957244<', '<-0.0020138316687904174<', '<0<']>>['<-0.03950959716204449<', '<-0.008224334667692809<', '<0<']>>['<-0.03579140846311252<', '<-0.013598754378747396<', '<0<']>>['<-0.03150606913268514<', '<-0.01807967531478988<', '<0<']>>['<-0.02682261358938636<', '<-0.02163884853899021<', '<0<']>>['<-0.021903630348792915<', '<-0.024275018810467796<', '<0<']>>['<-0.016901642262918733<', '<-0.026011260914467395<', '<0<']>>['<-0.0119561123 ...

# %%
# print(mesh_string)

# %% [markdown]
# ### Prototype Import Plots

# %%
# this cell opens to saved .txt file from cell above and converts it
# back into a list of lists of numbers
# This is the code block that will be used to import 
# data from this calculation , to the python script in blender that
# generates geometry

read_mesh = open("C:\\Users\chris\ChrisdeMontigny\\Nefari0 Repository\Python\Blender\mesh_data.txt","r")
is_read = read_mesh.read()
read_mesh.close()

read_list = list(is_read.split('>>')) # converts to python array
# list_index = read_list.split('<')
new_coords = []

# print(read_list[199])

for i in range(len(read_list)-1):
    list_index = read_list[i].split('<') # converts each array element into floats, stores in new_coord array
    coords = [float(list_index[1]),float(list_index[3]),float(list_index[5])]
    new_coords.append(coords)
    
print(new_coords)
# Out:
# [[1.0, 0.0, 0.0], [0.936939648986081, 0.14915487793726512, 0.0], [0.85560872822968, 0.27949823795820583, 0.0], [0.7599652159306065, 0.389491196385946, 0.0], [0.6539470308010685, 0.47828226384371386, 0.0], [0.5413707688110748, 0.5456610059585676, 0.0], [0.4258437373622978, 0.5919995223290313, 0.0], [0.31069026531524624, 0.6181844953175126, 0.0], [0.19889279518606565, 0.6255425326508197, 0.0], [0.09304782560539211, 0.6157614315563021, 0.0], [-0.004663624100621736, 0.5908098366120286, 0.0], [-0.09249170339184223, 0.5528575586493244, 0.0], [-0.16912054578711166, 0.5041985782105797, 0.0], [-0.23365942219525243, 0.4471784845243412, 0.0], [-0.2856236292893096, 0.38412780972793903, 0.0], [-0.3249066395407359, 0.3173024176496416, 0.0], [-0.3517451161782757, 0.24883180565338456, 0.0], [-0.3666784232837817, 0.18067588477685498, 0.0], [-0.37050424274237514, 0.11459052459595478, 0.0], [-0.36423185085177145, 0.052101890790586934, 0.0], [-0.34903451364778004, -0.005510629985816493, 0.0], [-0.32620233735828663, -0.05722332800363042, 0.0], [-0.2970967649593666, -0.10226947466506267, 0.0], [-0.2631077476655534, -0.14013375740774536, 0.0], [-0.22561444726223948, -0.17054067746411783, 0.0], [-0.18595014709357233, -0.1934378178233619, 0.0], [-0.14537187144086725, -0.20897493262421238, 0.0], [-0.10503503963274323, -0.21747982376009378, 0.0], [-0.06597331659798682, -0.21943195825089465, 0.0], [-0.02908366914731809, -0.21543474392421083, 0.0], [0.004883500171346116, -0.2061873244733923, 0.0], [0.035329390150404615, -0.19245668154551565, 0.0], [0.06180735925054489, -0.17505074477679972, 0.0], [0.08401943795097302, -0.15479311424128703, 0.0], [0.1018092907619808, -0.1324998971107588, 0.0], [0.11515216713030753, -0.10895905475316339, 0.0], [0.12414240556292473, -0.0849125510817515, 0.0], [0.12897906308435483, -0.061041490456472405, 0.0], [0.12995023415095286, -0.03795433623106469, 0.0], [0.1274166011587872, -0.016178211153129052, 0.0], [0.12179472467450175, 0.0038468001139846646, 0.0], [0.11354053758343359, 0.021770496840744533, 0.0], [0.10313345563019835, 0.03733276669240828, 0.0], [0.09106145945781301, 0.050361407306234826, 0.0], [0.0778074423010532, 0.060767860154168025, 0.0], [0.0638370549142498, 0.06854117712150584, 0.0], [0.049588216916427695, 0.07374055456692588, 0.0], [0.035462403136067334, 0.07648677375327088, 0.0], [0.02181775614352556, 0.0769528813635896, 0.0], [0.008964023156071697, 0.07535443040772176, 0.0], [-0.0028407321601429617, 0.07193958135542758, 0.0], [-0.013391734068914628, 0.06697933704476129, 0.0], [-0.02253754145907407, 0.0607581540796218, 0.0], [-0.03017869123911368, 0.05356513931106877, 0.0], [-0.036265114192069514, 0.045686003815926926, 0.0], [-0.040792513684163784, 0.03739590969817217, 0.0], [-0.04379790579888417, 0.028953308106804996, 0.0], [-0.045354521622082505, 0.020594831041235266, 0.0], [-0.04556626907861964, 0.012531265630257889, 0.0], [-0.044561943551607745, 0.004944608318487034, 0.0], [-0.04248936419957244, -0.0020138316687904174, 0.0], [-0.03950959716204449, -0.008224334667692809, 0.0], [-0.03579140846311252, -0.013598754378747396, 0.0], [-0.03150606913268514, -0.01807967531478988, 0.0], [-0.02682261358938636, -0.02163884853899021, 0.0], [-0.021903630348792915, -0.024275018810467796, 0.0], [-0.016901642262918733, -0.026011260914467395, 0.0], [-0.01195611232241568, -0.026891944059551417, 0.0], [-0.007191091048904121, -0.026979441101763563, 0.0], [-0.0027135030788380215, -0.026350694383362055, 0.0], [0.0013879459821034212, -0.0250937425665932, 0.0], [0.005043275730792964, -0.023304303438546763, 0.0], [0.008201195527738627, -0.02108249670754671, 0.0], [0.010828582482052559, -0.01852977874703954, 0.0], [0.012909535156970372, -0.015746148496696796, 0.0], [0.014444070195552144, -0.012827670704813068, 0.0], [0.015446531717146765, -0.0098643497605417, 0.0], [0.015943783889579944, -0.00693837484929277, 0.0], [0.01597325573474222, -0.0041227453559217735, 0.0], [0.01558090420160321, -0.001480274577260159, 0.0], [0.01481915708 ...

# %%
# experimental

# this cell opens to saved .txt file from cell above and converts it
# back into a list of lists of numbers
# This is the code block that will be used to import 
# data from this calculation , to the python script in blender that
# generates geometry

read_mesh = open("C:\\Users\chris\ChrisdeMontigny\\Nefari0 Repository\Python\Blender\mesh_data.txt","r")
is_read = read_mesh.read()
read_mesh.close()

read_list = list(is_read.split('>>')) # converts to python array
# list_index = read_list.split('<')
new_coords = []

# print(read_list[199])

for i in range(len(read_list)-1):
    list_index = read_list[i].split('<') # converts each array element into floats, stores in new_coord array
    coords = [float(list_index[1]),float(list_index[3]),float(list_index[5])]
#     print(i,list_index[3])
    new_coords.append(coords)
    
print(new_coords[1])
# Out:
# [0.936939648986081, 0.14915487793726512, 0.0]

# %%
# experimental
print(new_coords[0][0])
# Out:
# 4.0

# %%
# experimental
# print(type(new_coords[0][1]))
math1 = new_coords[0][1]
math2 = new_coords[1][0]
print(math1,math2)
print(math1+math2)
# Out:
# 3.85449571210911 -3.959798994974874
# -0.10530328286576429
